# %%
#from wit import Wit
import pandas as pd
import multiprocessing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
#from bs4 import BeautifulSoup
from collections import defaultdict
import requests
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 

# %matplotlib inline

# %% [markdown]
# # 1.Selected_comments_with_witai_sentiment_results
# ## import comment with side effects for query

# %%
SE_tem_l400 = pd.read_csv("wit_ai_sentment/SE_tem_l400.csv",index_col=0,header=None)[1]
SE_tem_l400 = SE_tem_l400.iloc[3:].astype(str)
idxs = list(SE_tem_l400.index)

# %%
first_quest2 = pd.read_csv("wit_ai_sentment/SE_tem_l400_first_request.ccv",index_col=0)

# %%
print("Total results:",len(first_quest2))
first_quest2.groupby('value').size()
# Out:
# Total results: 30689
# value
# negative    16765
# neutral     12010
# positive     1914
# dtype: int64

# %%
for i_n in first_quest2[first_quest2['value'] == 'negative'].sample(10)['text']:#.iloc[0]
    print(i_n+"\n")
# Out:
# I felt horrible (uncontrollable nausea, headaches, crazy mood changes, dry mouth) during the first month but I decided to stick with it since the side effects were &quot
#
# I only have minor cramps which is normal and so far the only side effect is I feel hungry after taking the pill at night
#
# I have not experienced any side effects
#
# Really scary vertigo side effects, severe headache on the left side of my head
#
# it seems I'm one of the few who didn't have any negative side effects from it.   Like I said, I had NO side effects.   Just because the side effects aren't there doesn't mean the pill isn't working
#
# The only bothersome side effect has been some increased urination urges during the night
#
# There are a few side effects, including out-of-nowhere jerking
#
# Aside from slight appetite suppression, I've experienced no side effects
#
# No negative side effects
#
# No weight gain, no headache, no problems with sleep or other side effects related to SSRI

# %%
for i_n in first_quest2[first_quest2['value'] == 'neutral'].sample(10)['text']:#.iloc[0]
    print(i_n+"\n")
# Out:
# I used Ortho-tri cyclen for 8 years, and had very few side effects
#
# I have no side effects, VL is still undetectable, and CD4 is steady
#
# That's keeping me sane and I am on week 4 overall: 16 days using medication the remainder trying to overcome side effects
#
# no major side effects
#
# We have had no side effects and we use it for major flare-ups as it is not intended for long term daily use
#
# I have had next to no side effects
#
# That being said, these type of medicines have different side effects for each individual, i.  there is no standard side effect
#
# The only side effect I've had is the &quot
#
# I'm still going to give it a try for another month to see if those side effects wear off.  I have no other side effects
#
# I took the pill around 40 hours later, and experienced no side effects

# %%
for i_n in first_quest2[first_quest2['value'] == 'positive'].sample(10)['text']:#.iloc[0]
    print(i_n+"\n")
# Out:
# I don't remember having side effects because I was so happy I got my cycle
#
# Used it for 7 years, no side effects, works great to reduce my Blood Pressure
#
# I took the 2 week trial and it worked great, no side effects, and I felt great, I went from 185-180 in the 2 weeks, I felt full right away, dehydrated so I was drinking ton's of water, craved no sweets, small portions filled me up fast, now I'm on the 7
#
# I used Mobic for 1 year with great results for knee pain andno side effects
#
# I was happy with that, and seeing no side effects, I went on to taking the next dose of 7.   The only side effects I had was an occasional dry mouth, which I battled by drinking more water, which is recommended with this drug anyways
#
# I've finally found something to help me make it through the night without side effects
#
# Another great thing about it is I don't have any side effects
#
# Oh my side effects dreams I was on a cooking show, gained a little weight
#
# Side effects are bad initially but now I am able to cope with side effects from this and I feel better now, less anxious and more calmer and happier
#
# I have all the side effects you have all mentioned but as everyone said, well worth it

# %% [markdown]
# # 2. Train the model using only these comment with side effects

# %%
import nltk
from nltk.tokenize import word_tokenize
import string
from nltk.stem.snowball import SnowballStemmer
import re
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
#from wordcloud import WordCloud

from sklearn.svm import SVC

## only need to remove punctuation and stemize
stemmer = SnowballStemmer('english')

def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
## remove special symbol
def rm_sym(df):
    df['review'] = df['review'].str.replace("&#039;",'\'')
    df['review'].head()
    df['rating_cate'] = ''
    df.loc[df['rating'] >= 7,'rating_cate'] = 'high'
    df.loc[df['rating'] <= 4,'rating_cate'] = 'low'
    df.loc[(df['rating'] > 4) & (df['rating'] < 7),'rating_cate'] = 'medium'
    return df

# %%
df = pd.read_csv('drugsCom_raw/drugsComTrain_raw.tsv',sep='\t',index_col=0)
df = rm_sym(df)


test = pd.read_csv("drugsCom_raw/drugsComTest_raw.tsv",sep='\t', index_col=0)
test = rm_sym(test)

# %%
train = pd.concat([df.loc[first_quest2.index], first_quest2],1)
## Generate table of words with their counts
con_vec = TfidfVectorizer(stop_words='english',tokenizer=tokenize)
X_train_p = con_vec.fit_transform(train['review'])
#y_train = train['rating_cate']
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/feature_extraction/text.py:301: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
negnornot = (train['value'] == "negative").astype(int)
negnornot.shape
# Out:
# (30689,)

# %%
X_train,X_test,y_train,y_test =  train_test_split(X_train_p,negnornot,test_size=0.25)

# %% [markdown]
# ## Logistic regression

# %%
lr = LogisticRegression(penalty='l1',multi_class='auto',solver='saga')
#lr.fit(X,target_3.iloc[:,0])

cv_score = cross_val_score(lr,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
cv_score
# Out:
# array([0.68886861, 0.67961418, 0.6835245 ])

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=300,n_jobs=-1)
rfc_cv_score = cross_val_score(rfc,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
rfc_cv_score
# Out:
# array([0.7632951 , 0.77111575, 0.7653806 ])

# %%
rfc = RandomForestClassifier(n_estimators=300,n_jobs=-1)
rfc.fit(X_train,y_train)
y_test_predict = rfc.predict(X_test)
accuracy_score(y_test,y_test_predict)
# Out:
# 0.8118076371692949

# %%
feature_importances = pd.DataFrame(rfc.feature_importances_,con_vec.get_feature_names())
feature_importances.sort_values(0,ascending=False)
# Out:
#                       0
# bad            0.011099
# effect         0.009980
# headach        0.005513
# horribl        0.005404
# year           0.005260
# work           0.005085
# onli           0.004601
# day            0.004482
# week           0.004296
# month          0.004151
# terribl        0.004109
# nausea         0.004071
# worst          0.003929
# start          0.003844
# ani            0.003821
# drug           0.003786
# feel           0.003616
# great          0.003519
# time           0.003505
# im             0.003480
# pain           0.003458
# medic          0.003422
# sever          0.003422
# ive            0.003408
# veri           0.003382
# like           0.003339
# becaus         0.003296
# help           0.003292
# just           0.003284
# tri            0.003276
# ...                 ...
# stsys          0.000000
# stubbi         0.000000
# incivek        0.000000
# incit          0.000000
# incidens       0.000000
# incd           0.000000
# 10377          0.000000
# inadequaci     0.000000
# inactivesugar  0.000000
# improvedbut    0.000000
# stugeron       0.000000
# improp         0.000000
# 157101         0.000000
# impost         0.000000
# implod         0.000000
# immunologist   0.000000
# immunoligist   0.000000
# immigran       0.000000
# immensli       0.000000
# immediatley    0.000000
# immeasur       0.000000
# immacul        0.000000
# imitrix        0.000000
# imbalanceacn   0.000000
# imatinib       0.000000
# illinoi        0.000000
# illeum         0.000000
# 15ish          0.000000
# il2            0.000000
# foreverrr      0.000000
#
# [24462 rows x 1 columns]

# %% [markdown]
# ### Gradient boosting classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(n_estimators=300)
gbc_cv_score = cross_val_score(gbc,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
gbc_cv_score
# Out:
# array([0.69721064, 0.68847758, 0.69890511])

# %% [markdown]
# ### SVM

# %% [markdown]
# #### poly

# %%
svm_poly = SVC(kernel='poly')
gbc_cv_score = cross_val_score(svm_poly,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
gbc_cv_score
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-d3d0a1d3284a> in <module>
#       1 svm_poly = SVC(kernel='poly')
# ----> 2 gbc_cv_score = cross_val_score(svm_poly,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
#       3 gbc_cv_score
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     400                                 fit_params=fit_params,
#     401                                 pre_dispatch=pre_dispatch,
# --> 402                                 error_score=error_score)
#     403     return cv_results['test_score']
#     404
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238             return_times=True, return_estimator=return_estimator,
#     239             error_score=error_score)
# --> 240         for train, test in cv.split(X, y, groups))
#     241
#     242     zipped_scores = list(zip(*scores))
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     210
#     211         seed = rnd.randint(np.iinfo('i').max)
# --> 212         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     213         # see comment on the other call to np.iinfo in this file
#     214
#
# /usr/local/lib/python3.5/dist-packages/sklearn/svm/base.py in _sparse_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     291                 sample_weight, self.nu, self.cache_size, self.epsilon,
#     292                 int(self.shrinking), int(self.probability), self.max_iter,
# --> 293                 random_seed)
#     294
#     295         self._warn_from_fit_status()
#
# sklearn/svm/libsvm_sparse.pyx in sklearn.svm.libsvm_sparse.libsvm_sparse_train()
#
# /usr/local/lib/python3.5/dist-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      23     """base matrix class for compressed row and column oriented matrices"""
#      24
# ---> 25     def __init__(self, arg1, shape=None, dtype=None, copy=False):
#      26         _data_matrix.__init__(self)
#      27
#
# KeyboardInterrupt:

# %% [markdown]
# #### linear

# %%
svm_lin = SVC(kernel='linear')
gbc_cv_score = cross_val_score(svm_lin,X_train,y_train,scoring='accuracy',cv=3,n_jobs=-1)
gbc_cv_score

# %% [markdown]
# ## Using LSTM to predict whether negative

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
#from bs4 import BeautifulSoup
from collections import defaultdict
#import requests
# %matplotlib inline
from sklearn.svm import SVC
from nltk.stem.snowball import SnowballStemmer

## remove special symbol

def clean_text(df_tem3,col):
    df_tem3[col] = df_tem3[col].str.replace("&#039;",'\'')
    df_tem3[col] = df_tem3[col].str.replace("\"","").str.lower()
    df_tem3[col] = df_tem3[col].str.replace( r"(\\r)|(\\n)|(\\t)|(\\f)|(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])|(&#039;)|(\d\s)|(\d)|(\/)","")
    df_tem3[col] = df_tem3[col].str.replace("\"","").str.lower()
    df_tem3[col] = df_tem3[col].str.replace( r"(\$)|(\-)|(\\)|(\s{2,})"," ")
    df_tem3[col].sample(1).iloc[0]

    stemmer = SnowballStemmer('english')
    df_tem3[col] = df_tem3[col].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split(" ")]))
    return df_tem3


np.random.seed(9)

# %%
import tensorflow as tf
import tensorflow 

#from tensorflow import tensorflow.keras

#from keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPool1D 
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Bidirectional



# fix random seed for reproducibility

MAX_NB_WORDS = 500
max_review_length = 500
EMBEDDING_DIM = 160

# %%
first_quest3 = first_quest2.copy()
first_quest3.columns = ['review', 'confidence', 'value']
df_tem3 = clean_text(first_quest3,'review')

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_tem3,test_size=0.2)

# %%
# Tokenize the data
tokenizer = Tokenizer(num_words = MAX_NB_WORDS, 
                      filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~',
                      lower=True, split=' ', char_level=False, 
                      oov_token=None, document_count=0)

tokenizer.fit_on_texts(train['review'])
train_sequences = tokenizer.texts_to_sequences(train['review'])
test_sequences = tokenizer.texts_to_sequences(test['review'])

# %%
# truncate and pad input sequences
X_train = sequence.pad_sequences(train_sequences, maxlen=max_review_length)
X_test = sequence.pad_sequences(test_sequences, maxlen = max_review_length)

# %%
word_index = tokenizer.word_index

print(X_train.shape, '<-- shape of train_data ready for val/train split.')
print(X_test.shape, '<-- shape of final_test_data ready for fedding to network.')
print(len(tokenizer.word_index), '<-- Length of Word Index')
# Out:
# (24551, 500) <-- shape of train_data ready for val/train split.
# (6138, 500) <-- shape of final_test_data ready for fedding to network.
# 6232 <-- Length of Word Index

# %%
y_train = (train['value'] == 'negative').astype(int)
y_test = (test['value'] == 'negative').astype(int)
print(y_train.shape, '<-- shape of train_data ready for val/train split.')
print(y_test.shape, '<-- shape of final_test_data ready for fedding to network.')
# Out:
# (24551,) <-- shape of train_data ready for val/train split.
# (6138,) <-- shape of final_test_data ready for fedding to network.

# %%
nb_words  = min(MAX_NB_WORDS, len(word_index))
lstm_out = max_review_length

model = Sequential()
model.add(Embedding(nb_words,EMBEDDING_DIM,input_length=max_review_length))
#model.add(Dropout(0.2))

## add conv using kernal No.32 and size 3x3, actiation='relu'(rm neg)
# model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
# model.add(MaxPool1D(pool_size=2))
model.add(Bidirectional(LSTM(50, return_sequences=True)))
#model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(50)))
#model.add(Attention(max_review_length))
model.add(Dense(1, activation = 'sigmoid'))

## one-code mutiple categories targets use 'categorical_crossentropy' not 'binary_crossentropy'
model.compile(loss='binary_crossentropy',optimizer='adam',metrics =['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 500, 160)          80000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 500, 100)          84400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100)               60400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 224,901
# Trainable params: 224,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


## if 4 steps without decreasing of loss in valid set, stop the trainning
batch = 32 
epoch = 40

early_stopping = EarlyStopping(patience = 4)

LSTM_model = model.fit(X_train, y_train, batch_size=batch, epochs=epoch,
                       validation_split=0.2,callbacks=[early_stopping], shuffle = True)

best_score = min(LSTM_model.history['val_loss'])
# Out:
# /home/ubuntu/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/ubuntu/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 19640 samples, validate on 4911 samples
# Epoch 1/40
# 19640/19640 [==============================] - 541s 28ms/step - loss: 0.4063 - acc: 0.8113 - val_loss: 0.3210 - val_acc: 0.8666
# Epoch 2/40
# 19640/19640 [==============================] - 525s 27ms/step - loss: 0.3189 - acc: 0.8674 - val_loss: 0.3047 - val_acc: 0.8754
# Epoch 3/40
# 19640/19640 [==============================] - 522s 27ms/step - loss: 0.2900 - acc: 0.8817 - val_loss: 0.2933 - val_acc: 0.8841
# Epoch 4/40
# 19640/19640 [==============================] - 529s 27ms/step - loss: 0.2674 - acc: 0.8910 - val_loss: 0.2850 - val_acc: 0.8847
# Epoch 5/40
# 19640/19640 [==============================] - 525s 27ms/step - loss: 0.2489 - acc: 0.8980 - val_loss: 0.2893 - val_acc: 0.8817
# Epoch 6/40
# 19640/19640 [==============================] - 527s 27ms/step - loss: 0.2359 - acc: 0.9049 - val_loss: 0.3160 - val_acc: 0.8735
# Epoch 7/40
# 19640/19640 [==============================] - 528s 27ms/step - loss: 0.2203 - acc: 0.9119 - val_loss: 0.3031 - val_acc: 0.8847
# Epoch 8/40
# 19640/19640 [==============================] - 525s 27ms/step - loss: 0.2107 - acc: 0.9175 - val_loss: 0.2993 - val_acc: 0.8811

# %%
LSTM_model_history = pd.DataFrame(LSTM_model.history)
file_name = "Wit_ai_" + "bilstm_2l.csv"
LSTM_model_history.to_csv('./model_report/' + file_name)

# %%
model.save('./model_report/Wit_ai_bilstm_2l.h5')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.models import load_model

model = load_model('./model_report/Wit_ai_bilstm_2l.h5')

accr = model.evaluate(X_test,y_test, batch_size = 100)
print(accr)
print("both 1 and 2 layers of directional LSTM works similiarly")
# Out:
# /home/ubuntu/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/ubuntu/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 6138/6138 [==============================] - 15s 3ms/step
# [0.31198260070602524, 0.8765070082776979]
# both 1 and 2 layers of directional LSTM works similiarly

# %%
unkn_data = pd.read_csv("web_scrap.csv",index_col=0)
unkn_data2 = unkn_data[['3','9','10']]
unkn_data2.columns = ['SE','SE_comments','comments']
unkn_data2 = unkn_data2.drop_duplicates()
unkn_data2['SE_YN'] = (unkn_data2['SE'] != ' No Side Effects').astype(int)
unkn_data2.groupby('SE_YN').size()
# Out:
# SE_YN
# 0    1213
# 1    2945
# dtype: int64

# %%
unkn_test = clean_text(unkn_data2,'SE_comments')

unkn_test_sequences = tokenizer.texts_to_sequences(unkn_test['SE_comments'])
X_unkn_test = sequence.pad_sequences(unkn_test_sequences, maxlen = max_review_length)
y_unkn_test = unkn_data2['SE_YN']

# %%
unkn_test_accr = model.evaluate(X_unkn_test,y_unkn_test, batch_size = 100)
print(unkn_test_accr)
# Out:
# 4158/4158 [==============================] - 11s 3ms/step
# [1.0742902643351442, 0.6577681576534783]

# %%
unkn_data2
# Out:
#                                   SE  \
# 0                Severe Side Effects
# 1              Moderate Side Effects
# 2                    No Side Effects
# 3      Extremely Severe Side Effects
# 4                Severe Side Effects
# 5                    No Side Effects
# 8                  Mild Side Effects
# 9                    No Side Effects
# 10                   No Side Effects
# 11                   No Side Effects
# 12             Moderate Side Effects
# 13                 Mild Side Effects
# 14             Moderate Side Effects
# 15             Moderate Side Effects
# 16             Moderate Side Effects
# 17             Moderate Side Effects
# 18                 Mild Side Effects
# 19               Severe Side Effects
# 20                 Mild Side Effects
# 21               Severe Side Effects
# 22             Moderate Side Effects
# 23               Severe Side Effects
# 24                 Mild Side Effects
# 25             Moderate Side Effects
# 26                 Mild Side Effects
# 27             Moderate Side Effects
# 28             Moderate Side Effects
# 29                 Mild Side Effects
# 30             Moderate Side Effects
# 31             Moderate Side Effects
# ...                              ...
# 7168                 No Side Effects
# 7169               Mild Side Effects
# 7170           Moderate Side Effects
# 7171                 No Side Effects
# 7172               Mild Side Effects
# 7173                 No Side Effects
# 7174               Mild Side Effects
# 7175               Mild Side Effects
# 7176               Mild Side Effects
# 7467           Moderate Side Effects
# 7742           Moderate Side Effects
# 7743               Mild Side Effects
# 7744               Mild Side Effects
# 7745             Severe Side Effects
# 7746               Mild Side Effects
# 7747               Mild Side Effects
# 7748                 No Side Effects
# 7749               Mild Side Effects
# 7750           Moderate Side Effects
# 7751   Extremely Severe Side Effects
# 7752                 No Side Effects
# 7753           Moderate Side Effects
# 7754           Moderate Side Effects
# 7755               Mild Side Effects
# 7756               Mild Side Effects
# 7757               Mild Side Effects
# 7758               Mild Side Effects
# 7759                 No Side Effects
# 7760           Moderate Side Effects
# 7761           Moderate Side Effects
#
#                                             SE_comments  \
# 0      a veri uncomfort inner restless was the worst...
# 1      i becam drowsi howev with adequ sleep hrs the...
# 2                        no side effect have been notic
# 3      but it caus memori loss and again an incid in...
# 4      headach first morn at am that was reliev with...
# 5                                           none so far
# 8         dryness slight red and a small amount of peel
# 9      i toler the medic veri well i didnt experi an...
# 10                                                 none
# 11                                    none i am awar of
# 12                       skin peel and dri and chap lip
# 13                                              dri lip
# 14                 pain muscl problem with see at night
# 15     while it help my face it consequ dri out the ...
# 16                                    red skin dri skin
# 17     my face skin got a bit too dri but manag with...
# 18     dri skin and lip increa suscept to develop bl...
# 19     made it wor befor better left me with scar dr...
# 20     the side effect were minim and consist of dri...
# 21          bald sensit to sunlight night vision blurri
# 22            some day of sever depress extrem dri skin
# 23     hairloss extrem dri skin itchi rai cholestoro...
# 24     my skin got veri dri includ my lip i had to u...
# 25                            veri dri skin bloodi nose
# 26     dri lip solv by lip balm mild dri mouth solv ...
# 27     dri skin which was easili taken care of with ...
# 28                    chap lip dri skin sensit to light
# 29     side effect includ moder to sever dri skin th...
# 30     my skin peel great praticular around my lip a...
# 31     veri dri mouth nose and skin it essenti dri u...
# ...                                                 ...
# 7168   no side effect were notic the outbreak itself...
# 7169                         ocass diarrhea and headach
# 7170   due to my chronic gastriti i had minor stomac...
# 7171                         didnt feel ani side effect
# 7172   the first time i took this medicin was dure t...
# 7173                 no side effect cold sore disappear
# 7174                  slight dizzi and tire veri minor
# 7175                                              dizzi
# 7176   veri few side effect were experienc slight up...
# 7467   the side effect of warfarin on me did not bec...
# 7742   the side effect of take zomig for me are inab...
# 7743                  mild initi discomfort in the neck
# 7744                                   fatigu dri mouth
# 7745                                        stomach ach
# 7746               the on side affect note is feel tire
# 7747   veri mild feel of flush or someth like be lig...
# 7748                     i had no treatment side effect
# 7749   within about min i start feel mild tingl in m...
# 7750   drowsi occass nauseau though part of the side...
# 7751   sharon complain of sever chest pain from the ...
# 7752                                               none
# 7753   the drug administr usual result in nausea and...
# 7754   sensit to heat eg hot water on scalp and fing...
# 7755   the side effect were not that bad at all im a...
# 7756    make my skin feel a littl ting and make me tire
# 7757   slight drowsi and foggi sensit to heat in finger
# 7758   general i fell a littl dull or numb in the he...
# 7759   thank there are none i am abl to function com...
# 7760   sometim heavi breath palpit feel of a rush of...
# 7761   i feel sleepi but i would rather feel this wa...
#
#                                                comments  SE_YN
# 0      I was prescribed Abilify (15mg/daily) to assi...      1
# 1      the abilify decreased the need for daily klon...      1
# 2      I take one pill of each 1st thing in the am.....      0
# 3      I am only taking ativan & getting psychologic...      1
# 4      Not much to tell.  I was just starting treatm...      1
# 5      My doctor added Abilify to my 60 mg of Cymbal...      0
# 8      The combination of clindamycin and benzoyl pe...      1
# 9      I was required to take Accolate for three mon...      0
# 10     I have always been normal weight, but after m...      0
# 11     Taken once daily in combination with Hyzaar. ...      0
# 12     I took 50 mg a day for 4 months as a last res...      1
# 13     I took this drug twice - both times for 3 mon...      1
# 14     This drug is highly teratogenic ,females must...      1
# 15     This was an oral treatment and the regimine w...      1
# 16     took pill every day and applied benzoil perox...      1
# 17     took 30 mg daily and had my blood work monito...      1
# 18     I am 43 now but took Accutane back in my earl...      1
# 19                                        daily tablets      1
# 20     Overall it was helpful but there is alot invo...      1
# 21     TAKE 1 PILL A DAY, BLOOD TOXICITY TESTS EVERY...      1
# 22     In the first few weeks I couldn´t see any cha...      1
# 23     Treatment period is 3 months/12 weeks. Dosage...      1
# 24     I had monthly lab work and doctor's visits to...      1
# 25     took accutane orally aswell as applied certai...      1
# 26     I was started on a low dose, which cleared my...      1
# 27     I would take 2x20mg pills daily. I needed to ...      1
# 28     I was started off with a .5 mg dosage once a ...      1
# 29     Drug was taken in gelatin tablet at 0.5 mg pe...      1
# 30     I took one pill per day for 6 months, at the ...      1
# 31              2 capsules daily and lots of chapstick.      1
# ...                                                 ...    ...
# 7168   At the first sign of a possible outbreak I wo...      0
# 7169   I began getting cold sores about 5 years ago,...      1
# 7170   The treatment was started on the second day o...      1
# 7171   I've been suffering from cold sores all my li...      0
# 7172   Once a day, everyday for the next four months...      1
# 7173   Take two 1 gram tablets at first sign of cold...      0
# 7174      2x 1000mg tablets every 12 hours for 1 day.        1
# 7175   I got it from a girl I was dating on and off ...      1
# 7176   Prescribed Valtrex for regular outbreak of co...      1
# 7467   Treatment consisted of simply taking 3 mg. of...      1
# 7742   I can take Zomig to alleviate any headache pa...      1
# 7743                     Prescribed for migraine relief      1
# 7744          take a pill at the onset of a migraine.        1
# 7745   I had to take a pill when I felt any signs of...      1
# 7746   I feel tired and usually need to take a short...      1
# 7747   As soon as I determine this is a migraine, (s...      1
# 7748   It was recommended that as soon as I felt the...      0
# 7749   My insurance covers it like a normal RX, but ...      1
# 7750                                  Please see above.      1
# 7751   She took one pill at the Doctors office and s...      1
# 7752   I take one 2.5mg tablet, usually after suffer...      0
# 7753   A single pill is to be taken at migraine onse...      1
# 7754                                               None      1
# 7755   I suffered with migraines since I've been 22 ...      1
# 7756   Take it as soon as i feel headache coming on ...      1
# 7757   Half a pill at onset of migraine, followed if...      1
# 7758   Since insurance only covers 2 per week and th...      1
# 7759                                               None      0
# 7760   I take 1 2.5mg orodispersible tablet. After 3...      1
# 7761   Taken PRN, only prescribed 6 tabs every 20 days       1
#
# [4158 rows x 4 columns]
