# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.proportion import proportions_chisquare
from scipy.stats import chisquare

from bs4 import BeautifulSoup
from collections import defaultdict
import requests
# %matplotlib inline
import re
from collections import Counter
import string

# %%
def drug_link(letter):
    '''
    INPUT: string
    OUTPUT: list of strings

    Take a query and return a list of all of the etsy usernames who have a
    result on the first page of that query result.
    '''

    url = "http://www.druglib.com/drugindex/rating/%s/" % letter
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    search = soup.find_all('a', attrs={'href':re.compile('/ratingsreviews/.*')})
    drug_link = ["http://www.druglib.com"+ a['href'] for a in search]
    return drug_link#[a for a in search]


def scrap_one_page(test_link):
    html = requests.get(test_link).text
    soup = BeautifulSoup(html, 'html.parser')

    ## age_geneder
    age_geneder = soup.find_all('h2')
    age_geneder = [a.contents[0] for a in age_geneder]

    ## rating
    rating =soup.find_all('img',attrs={'hight':"18px"})
    rating = [a['src'] for a in rating]
    rating = [rating[x:x+10] for x in range(0, len(rating),10)]
    rating = [Counter(a)['/img/red_star.gif'] for a in rating ]

    all_contents = [a.contents[0] for a in soup.find_all('td',attrs={'class':"review3"})]
    ## effective
    effective = [a for a in all_contents if 'Effective' in a]

    ## effects
    effects = [a for a in all_contents if 'Effects' in a]

    all_contents_sorted = []
    i = 0
    for x in range(0, len(all_contents),10):
        all_contents_sorted.append([age_geneder[i]]+[rating[i]] + all_contents[x+1:x+10])

    return all_contents_sorted

# %%
all_lo_list = []
for l in string.ascii_lowercase:
    oletter_alist =[]
    for each in  drug_link(l):
        temp_list = scrap_one_page(each)
        oletter_alist = oletter_alist + temp_list
    all_lo_list = all_lo_list + oletter_alist

# %%
df_ws = pd.DataFrame(all_lo_list)
df_ws.to_csv("web_scrap.csv")

# %%
df_ws.head()
# Out:
#                                               0   1                        2   \
# 0  Abilify review by  26 year old female patient   3     Marginally Effective
# 1  Abilify review by  26 year old female patient   3         Highly Effective
# 2  Abilify review by  26 year old female patient   3         Highly Effective
# 3  Abilify review by  26 year old female patient   3   Considerably Effective
# 4  Abilify review by  26 year old female patient   3              Ineffective
#
#                                3   \
# 0             Severe Side Effects
# 1           Moderate Side Effects
# 2                 No Side Effects
# 3   Extremely Severe Side Effects
# 4             Severe Side Effects
#
#                                                   4   \
# 0                                   bipolar disorder
# 1                                            bipolar
# 2                                 depression/anxiety
# 3   depression not resolved with antidepressant d...
# 4                                            bipolar
#
#                                                   5   \
# 0       15mg  taken daily for the period of 12 weeks
# 1          10mg  taken 1/day for the period of 8 mos
# 2       2 mg  taken daily for the period of 3 months
# 3   started out at 5mg the 10 & last 15mg  taken ...
# 4   2mg to start  taken once daily for the period...
#
#                                                   6   \
# 0                                               none
# 1                bipolar mood disorder, acne, asthma
# 2                                            anxiety
# 3   Add, depression, poss. bipolar type 2, PTSD, ...
# 4                                            anxiety
#
#                                                   7   \
# 0                               Cymbalta, 90mg/daily
# 1   zoloft, wellbutrin, clonazepam, tretinoin, cl...
# 2                                            Lexapro
# 3   vyvance, ativan lisinopril, zantac, viville d...
# 4                                           klonopin
#
#                                                   8   \
# 0   I didn't notice any benefit at all. Supposedl...
# 1   I had severe depression with agitation and mi...
# 2   Within 1 week of taking the cocktail of Abili...
# 3   While on abilify I can honestly say the depre...
# 4            None due to the short time taking drug.
#
#                                                   9   \
# 0   A very uncomfortable inner restlessness was t...
# 1   I became drowsy, however, with adequate sleep...
# 2                  no side effects have been noticed
# 3    but it caused memory loss and again an incid...
# 4   Headache first morning at 4AM that was reliev...
#
#                                                   10
# 0   I was prescribed Abilify (15mg/daily) to assi...
# 1   the abilify decreased the need for daily klon...
# 2   I take one pill of each 1st thing in the am.....
# 3   I am only taking ativan & getting psychologic...
# 4   Not much to tell.  I was just starting treatm...
